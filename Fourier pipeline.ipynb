# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import log, square, sqrt, power, arange, ones, zeros, isscalar,\
    array, outer, pi, sin, cos, expand_dims, repeat, full, concatenate, ravel
from numpy.random import normal
from scipy.optimize import least_squares, minimize
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from Module.baseModule.bayesFlexibleFourier import *
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# functions for loading the datasets
def load_stock():
    df_stock = pd.read_csv('NSQ_OneYear100test_Sept21.csv', 
                       usecols=['Local_Date_Time','RIC','Open','High','Low','Close','VWAP','NumberOfTrades','Volume'],
                       dtype={'Local_Date_Time': str,
                              'RIC': str, 
                              'Open': np.float64,
                              'High': np.float64,
                              'Low': np.float64,
                              'Close': np.float64,
                              'VWAP': np.float64,
                              'NumberOfTrades': int,
                              'Volume': int},
                       skipinitialspace=True,
                       parse_dates=True)
    return df_stock

def load_stockqqq():
    df_stockqqq = pd.read_csv('QQQ_OneYear100test_Sept21.csv', 
                   usecols=['Local_Date_Time','RIC','Open','High','Low','Close','VWAP','NumberOfTrades','Volume'],
                   dtype={'Local_Date_Time': str,
                          'RIC': str, 
                          'Open': np.float64,
                          'High': np.float64,
                          'Low': np.float64,
                          'Close': np.float64,
                          'VWAP': np.float64,
                          'NumberOfTrades': int,
                          'Volume': int},
                   skipinitialspace=True,
                   parse_dates=True)
    return df_stockqqq

def load_auction():
    df_auction = pd.read_csv('NSQ_OneYear100closeA_Sept21.csv',
                          skipinitialspace=True,
                          parse_dates=True)
    return df_auction

def load_auctionqqq():
    df_auctionqqq = pd.read_csv('QQQ_OneYear100closeA_Sept21.csv',
                      skipinitialspace=True,
                      parse_dates=True)
    return df_auctionqqq

# %%
# function for loading the trade data
def load_stockdata(df_stock, df_stockqqq, stock_name):
    #NSQ_OneYear100closeA_Sept21.csv
    df_stockRIC = df_stock[df_stock['RIC'] == stock_name]
    df_stockRIC['Date'] = pd.to_datetime(df_stockRIC['Local_Date_Time']).dt.date
    df_stockqqq['Date'] = pd.to_datetime(df_stockqqq['Local_Date_Time']).dt.date
    
    return df_stockRIC, df_stockqqq

# %%
# function for loading the auction price data
def load_auctiondata(df_auction, df_auctionqqq, stock_name):
    df_auctionRIC = df_auction[df_auction['RIC'] == stock_name]
    df_auctionRIC['Date'] = pd.to_datetime(df_auctionRIC['Local_Date_Time']).dt.date
    df_auctionqqq['Date'] = pd.to_datetime(df_auctionqqq['Local_Date_Time']).dt.date
    
    return df_auctionRIC, df_auctionqqq

# %%
# data processing
def get_voldf(df_stockRIC, df_auctionRIC):
    dates = df_stockRIC['Date'].unique()
    dates_final = []
    stocks = []
    daily_return = []
    auction_log_returns = []
    auction_log_returns_340350 = []
    daily_volatility = []
    daily_volatility_minus4pm = []
    avg_20day_volatility = []

    for date in dates:

        stock_today = df_stockRIC[df_stockRIC['Date'] == date]
        df_auctionRIC_today = df_auctionRIC[df_auctionRIC['Date'] == date]
        stock_today = stock_today.set_index(pd.DatetimeIndex(stock_today['Local_Date_Time']))
        stock_today_10min_max = pd.DataFrame(stock_today['High'].resample("10T").max())
        stock_today_10min_min = pd.DataFrame(stock_today['Low'].resample("10T").min())
        stock_today_10min_open = pd.DataFrame(stock_today['Open'].resample("10T").first())
        stock_today_10min_close = pd.DataFrame(stock_today['Close'].resample("10T").last())
        stock_today_10min = stock_today_10min_max.join(stock_today_10min_min)
        stock_today_10min = stock_today_10min.join(stock_today_10min_open)
        stock_today_10min = stock_today_10min.join(stock_today_10min_close)

        # Garman and Klass Volatility formula
        stock_today_10min['Volatility'] = np.sqrt(0.5*np.square(np.log(stock_today_10min['High']/stock_today_10min['Low'])) - (2*np.log(2)-1)*np.square(np.log(stock_today_10min['Close']/stock_today_10min['Open'])))
        #stock_today_10min['log_returns'] = abs(np.log(stock_today_10min['Close']/stock_today_10min['Open'])) # alternate volatility formula

        vol_today = [val for val in stock_today_10min['Volatility'].values]
        return_today = (stock_today_10min['Close']/stock_today_10min['Open']).values

        if len(vol_today) != 39: # Skip if there are fewer than 390 minutes of trading data
            continue

        # Dates for which the trade data is complete
        dates_final.append(date)

        # Change the 39th 10min interval to include the auction price (instead of close)
        auction_volatility = np.sqrt(0.5*np.square(np.log(stock_today_10min['High'][-1]/stock_today_10min['Low'][-1])) - (2*np.log(2)-1)*np.square(np.log(df_auctionRIC_today['Price'].iloc[0]/stock_today_10min['Open'][-1])))
        vol_today[-1] = auction_volatility

        # 10 minute interval volatility * number of complete trade days
        stocks.append(vol_today)

        # Daily raw return
        daily_return.append(return_today)

        # Auction Volatility Information
        auction_log_returns_today = abs(np.log(df_auctionRIC_today['Price'].iloc[0]/stock_today_10min['Open'][-1]))
        auction_log_returns.append(auction_log_returns_today)

        # Naive Auction Volatility Estimate (Volatility between 3:40pm and 3:50pm)
        auction_log_returns_today_340350 = abs(np.log(stock_today_10min['Open'][-1]/stock_today_10min['Open'][-2]))
        auction_log_returns_340350.append(auction_log_returns_today_340350)

        # Average daily volatility (later used for EWMA 20Day)
        daily_volatility.append(sum(vol_today))
        daily_volatility_minus4pm.append(sum(vol_today[:-1]))

    daily_return = np.array(daily_return)
    vol_df = pd.DataFrame({'Date':dates_final, 'daily_volatility': daily_volatility, 'daily_volatility_minus4pm': daily_volatility_minus4pm})
    vol_df['volatility_ewma20'] = np.array([None] + [i for i in vol_df['daily_volatility'].ewm(span=20).mean()][:-1])

    stocks = stocks[20:]
    stocks = np.vstack(stocks).T # Training data for Anderson model
    avg_20day_volatility_raw = np.array(vol_df['volatility_ewma20'])
    avg_20day_volatility = np.array(vol_df['volatility_ewma20'][20:]) # Sigma_t input for Anderson model
    
    stocks200 = stocks.T
    stocks200 = stocks200[:200].T
    avg_20day_volatility200 = avg_20day_volatility[:200]
    
    return vol_df

# %%
########### FOURIER MOVING WINDOW (20Days) ###########
def process_data_moving_window(df_stockRIC, df_auctionRIC):
    dates = df_stockRIC['Date'].unique()
    dates_final = []
    stocks = []
    daily_return = []
    auction_log_returns = []
    auction_log_returns_340350 = []
    daily_volatility = []
    daily_volatility_minus4pm = []
    avg_20day_volatility = []

    for date in dates:
        
        stock_today = df_stockRIC[df_stockRIC['Date'] == date]
        df_auctionRIC_today = df_auctionRIC[df_auctionRIC['Date'] == date]
        stock_today = stock_today.set_index(pd.DatetimeIndex(stock_today['Local_Date_Time']))
        stock_today_10min_max = pd.DataFrame(stock_today['High'].resample("10T").max())
        stock_today_10min_min = pd.DataFrame(stock_today['Low'].resample("10T").min())
        stock_today_10min_open = pd.DataFrame(stock_today['Open'].resample("10T").first())
        stock_today_10min_close = pd.DataFrame(stock_today['Close'].resample("10T").last())
        stock_today_10min = stock_today_10min_max.join(stock_today_10min_min)
        stock_today_10min = stock_today_10min.join(stock_today_10min_open)
        stock_today_10min = stock_today_10min.join(stock_today_10min_close)
        
        # Garman and Klass Volatility formula
        stock_today_10min['Volatility'] = np.sqrt(0.5*np.square(np.log(stock_today_10min['High']/stock_today_10min['Low'])) - (2*np.log(2)-1)*np.square(np.log(stock_today_10min['Close']/stock_today_10min['Open'])))   
        vol_today = [val for val in stock_today_10min['Volatility'].values]
        
        if len(vol_today) != 39: # Skip if there are fewer than 390 minutes of trading data
            continue
            
        # Dates for which the trade data is complete
        dates_final.append(date)
        
        # Change the 39th 10min interval to include the auction price (instead of close)
        auction_volatility = np.sqrt(0.5*np.square(np.log(stock_today_10min['High'][-1]/stock_today_10min['Low'][-1])) - (2*np.log(2)-1)*np.square(np.log(df_auctionRIC_today['Price'].iloc[0]/stock_today_10min['Open'][-1])))
        vol_today[-1] = auction_volatility
        
        # 10 minute interval volatility * number of complete trade days
        stocks.append(vol_today)
            
        # Auction Log Return Information
        auction_log_returns_today = abs(np.log(df_auctionRIC_today['Price'].iloc[0]/stock_today_10min['Open'][-1]))
        auction_log_returns.append(auction_log_returns_today)
        
        # Naive Auction Log Return Estimate (Volatility between 3:40pm and 3:50pm)
        auction_log_returns_today_340350 = abs(np.log(stock_today_10min['Open'][-1]/stock_today_10min['Open'][-2]))
        auction_log_returns_340350.append(auction_log_returns_today_340350)
        
        # Average daily volatility (later used for EWMA 20Day)
        daily_volatility.append(sum(vol_today))
        daily_volatility_minus4pm.append(sum(vol_today[:-1]))

    # daily_return = np.array(daily_return)
    vol_df = pd.DataFrame({'Date':dates_final, 'daily_volatility': daily_volatility, 'daily_volatility_minus4pm': daily_volatility_minus4pm})
    vol_df['volatility_ewma20'] = np.array([None] + [i for i in vol_df['daily_volatility'].ewm(span=20).mean()][:-1])

    stocks = np.vstack(stocks)[20:].T # Training data for Anderson model
    avg_20day_volatility = np.array(vol_df['volatility_ewma20'])[20:]

    return stocks, avg_20day_volatility

# %%
# fourier 2A - Sliding window 
def fourier2A_results(stocks, avg_20day_volatility, J, P):
    actual_fourier_window = []
    predicted_fourier_window = []
    
    for i in range(211):
        
        if i % 50 == 0:
            print(i/210, "done")
            
        stocks_window = stocks[:,i:i+20]
        avg_20day_volatility_window = avg_20day_volatility[i:i+20]
        fourier_window = flexible_fourier_regression(N=39, di=[], J=J, P=P) # 39 10-minute intervals in each trade day
        res_window = fourier_window.train(stocks_window, avg_20day_volatility_window, 0.0000005)
        #print("optimizer success: {}".format(res_window.success))
        #print("objective function (mse): {:.8f}".format(res_window.fun))
        
        # No Bayes
        result = fourier_window.predict(avg_20day_volatility[i+20])
        
        actual_fourier_window.append(stocks.T[i+20][-1])
        predicted_fourier_window.append(result[-1][0])
        #print(i)

    MAE = mean_absolute_error(actual_fourier_window, predicted_fourier_window)
    MSE = mean_squared_error(actual_fourier_window, predicted_fourier_window)
    R2 =r2_score(actual_fourier_window, predicted_fourier_window)
    
    return MAE, MSE, R2, fourier_window, predicted_fourier_window

# %%
# fourier 2B - Sliding window - Adaptive
def fourier2B_results(stocks, avg_20day_volatility, fourier_window, J, P):
    actual_fourier_window = []
    predicted_fourier_window = []

    for i in range(211):
        # After Bayes
        #print(i)
        
        bayes_dayVol = fourier_window.vol_update(stocks.T[i+20,:39], avg_20day_volatility[i+20], tol=1e-8)
        result = fourier_window.predict(bayes_dayVol)
        
        actual_fourier_window.append(stocks.T[i+20][-1])
        predicted_fourier_window.append(result[-1][0])
        
        
    MAE = mean_absolute_error(actual_fourier_window, predicted_fourier_window)
    MSE = mean_squared_error(actual_fourier_window, predicted_fourier_window)
    R2 =r2_score(actual_fourier_window, predicted_fourier_window)

    return MAE, MSE, R2, actual_fourier_window

# %%
# fourier 2C - Sliding window - Adaptive
def fourier2C_results(vol_df, actual_fourier_window, predicted_fourier_window):
    vol_df_window = vol_df[40:]
    vol_df_window['volatility_fourier_window'] = predicted_fourier_window
    vol_df_window['daily_volatility_minus4pm_yest'] = vol_df_window['daily_volatility_minus4pm'].shift(1)
    vol_df_window['volatility_fourier_2c'] = vol_df_window['daily_volatility_minus4pm']/vol_df_window['daily_volatility_minus4pm_yest']*vol_df_window['volatility_fourier_window']
    predicted_fourier_window2C = np.array(vol_df_window['volatility_fourier_2c'])

    MAE = mean_absolute_error(actual_fourier_window[1:], predicted_fourier_window2C[1:])
    MSE = mean_squared_error(actual_fourier_window[1:], predicted_fourier_window2C[1:])
    R2 = r2_score(actual_fourier_window[1:], predicted_fourier_window2C[1:])

    return MAE, MSE, R2

# %%
# combine all functions 
def results(df_stock, df_stockqqq, df_auction, df_auctionqqq, stock_name, J=1, P=15):
    
    df_stockRIC, df_stockqqq = load_stockdata(df_stock, df_stockqqq, stock_name)
    df_auctionRIC, df_auctionqqq = load_auctiondata(df_auction, df_auctionqqq, stock_name)
    vol_df = get_voldf(df_stockRIC, df_auctionRIC)
    
    stocks, avg_20day_volatility = process_data_moving_window(df_stockRIC, df_auctionRIC)
    MAE_2a, MSE_2a, R2_2a, fourier_window, predicted_fourier_window = fourier2A_results(stocks, avg_20day_volatility, J, P)
    MAE_2b, MSE_2b, R2_2b, actual_fourier_window = fourier2B_results(stocks, avg_20day_volatility, fourier_window, J, P)
    MAE_2c, MSE_2c, R2_2c = fourier2C_results(vol_df, actual_fourier_window, predicted_fourier_window)

    data = {
        "Metrics": ["Fourier Auction Vol (2A)", "Fourier Auction Vol Adaptive (2B)", "Fourier Auction Vol/ratio (2C)"],
        "MAE": [MAE_2a, MAE_2b, MAE_2c],
        "MSE": [MSE_2a, MSE_2b, MSE_2c],
        "R^2": [R2_2a, R2_2b, R2_2c]
    }
    
    pd.set_option('display.float_format',
      lambda x: '{:,.4f}'.format(x) if abs(x) >0.01 else '{:,.3e}'.format(x))
    
    table = pd.DataFrame(data, index=None)
    print(stock_name)
    display(table)

# %% [markdown]
# # Run the code

# %%
# load the datasets
df_stock = load_stock()
df_stockqqq = load_stockqqq()
df_auction = load_auction()
df_auctionqqq = load_auctionqqq()

# %%
# choose interested stocks
stock_list = ["MSFT.O", "AAPL.O", "GOOGL.O", "MRNA.O", "INTC.O", "PEP.O",
              "ZM.O", "EBAY.O", "PTON.O"]

for stock_name in stock_list:
    results(df_stock, df_stockqqq, df_auction, df_auctionqqq, stock_name, J=1, P=15)
# Out:
# MSFT.O
# 0.0 done
# 0.23809523809523808 done
# 0.47619047619047616 done
# 0.7142857142857143 done
# 0.9523809523809523 done
# 0
# Model fit success: True
# 1
# Model fit success: True
# 2
# Model fit success: True
# 3
# Model fit success: True
# 4
# Model fit success: True
# 5
# Model fit success: True
# 6
# Model fit success: True
# 7
# Model fit success: True
# 8
# Model fit success: True
# 9
# Model fit success: True
# 10
# Model fit success: True
# 11
# Model fit success: True
# 12
# Model fit success: True
# 13
# Model fit success: True
# 14
# Model fit success: True
# 15
# Model fit success: True
# 16
# Model fit success: True
# 17
# Model fit success: True
# 18
# Model fit success: True
# 19
# Model fit success: True
# 20
# Model fit success: True
# 21
# Model fit success: True
# 22
# Model fit success: True
# 23
# Model fit success: True
# 24
# Model fit success: True
# 25
# Model fit success: True
# 26
# Model fit success: True
# 27
# Model fit success: True
# 28
# Model fit success: True
# 29
# Model fit success: True
# 30
# Model fit success: True
# 31
# Model fit success: True
# 32
# Model fit success: True
# 33
# Model fit success: True
# 34
# Model fit success: True
# 35
# Model fit success: True
# 36
# Model fit success: True
# 37
# Model fit success: True
# 38
# Model fit success: True
# 39
# Model fit success: True
# 40
# Model fit success: True
# 41
# Model fit success: True
# 42
# Model fit success: True
# 43
# Model fit success: True
# 44
# Model fit success: True
# 45
# Model fit success: True
# 46
# Model fit success: True
# 47
# Model fit success: True
# 48
# Model fit success: True
# 49
# Model fit success: True
# 50
# Model fit success: True
# 51
# Model fit success: True
# 52
# Model fit success: True
# 53
# Model fit success: True
# 54
# Model fit success: True
# 55
# Model fit success: True
# 56
# Model fit success: True
# 57
# Model fit success: True
# 58
# Model fit success: True
# 59
# Model fit success: True
# 60
# Model fit success: True
# 61
# Model fit success: True
# 62
# Model fit success: True
# 63
# Model fit success: True
# 64
# Model fit success: True
# 65
# Model fit success: True
# 66
# Model fit success: True
# 67
# Model fit success: True
# 68
# Model fit success: True
# 69
# Model fit success: True
# 70
# Model fit success: True
# 71
# Model fit success: True
# 72
# Model fit success: True
# 73
# Model fit success: True
# 74
# Model fit success: True
# 75
# Model fit success: True
# 76
# Model fit success: True
# 77
# Model fit success: True
# 78
# Model fit success: True
# 79
# Model fit success: True
# 80
# Model fit success: True
# 81
# Model fit success: True
# 82
# Model fit success: True
# 83
# Model fit success: True
# 84
# Model fit success: True
# 85
# Model fit success: True
# 86
# Model fit success: True
# 87
# Model fit success: True
# 88
# Model fit success: True
# 89
# Model fit success: True
# 90
# Model fit success: True
# 91
# Model fit success: True
# 92
# Model fit success: True
# 93
# Model fit success: True
# 94
# Model fit success: True
# 95
# Model fit success: True
# 96
# Model fit success: True
# 97
# Model fit success: True
# 98
# Model fit success: True
# 99
# Model fit success: True
# 100
# Model fit success: True
# 101
# Model fit success: True
# 102
# Model fit success: True
# 103
# Model fit success: True
# 104
# Model fit success: True
# 105
# Model fit success: True
# 106
# Model fit success: True
# 107
# Model fit success: True
# 108
# Model fit success: True
# 109
# Model fit success: True
# 110
# Model fit success: True
# 111
# Model fit success: True
# 112
# Model fit success: True
# 113
# Model fit success: True
# 114
# Model fit success: True
# 115
# Model fit success: True
# 116
# Model fit success: True
# 117
# Model fit success: True
# 118
# Model fit success: True
# 119
# Model fit success: True
# 120
# Model fit success: True
# 121
# Model fit success: True
# 122
# Model fit success: True
# 123
# Model fit success: True
# 124
# Model fit success: True
# 125
# Model fit success: True
# 126
# Model fit success: True
# 127
# Model fit success: True
# 128
# Model fit success: True
# 129
# Model fit success: True
# 130
# Model fit success: True
# 131
# Model fit success: True
# 132
# Model fit success: True
# 133
# Model fit success: True
# 134
# Model fit success: True
# 135
# Model fit success: True
# 136
# Model fit success: True
# 137
# Model fit success: True
# 138
# Model fit success: True
# 139
# Model fit success: True
# 140
# Model fit success: True
# 141
# Model fit success: True
# 142
# Model fit success: True
# 143
# Model fit success: True
# 144
# Model fit success: True
# 145
# Model fit success: True
# 146
# Model fit success: True
# 147
# Model fit success: True
# 148
# Model fit success: True
# 149
# Model fit success: True
# 150
# Model fit success: True
# 151
# Model fit success: True
# 152
# Model fit success: True
# 153
# Model fit success: True
# 154
# Model fit success: True
# 155
# Model fit success: True
# 156
# Model fit success: True
# 157
# Model fit success: True
# 158
# Model fit success: True
# 159
# Model fit success: True
# 160
# Model fit success: True
# 161
# Model fit success: True
# 162
# Model fit success: True
# 163
# Model fit success: True
# 164
# Model fit success: True
# 165
# Model fit success: True
# 166
# Model fit success: True
# 167
# Model fit success: True
# 168
# Model fit success: True
# 169
# Model fit success: True
# 170
# Model fit success: True
# 171
# Model fit success: True
# 172
# Model fit success: True
# 173
# Model fit success: True
# 174
# Model fit success: True
# 175
# Model fit success: True
# 176
# Model fit success: True
# 177
# Model fit success: True
# 178
# Model fit success: True
# 179
# Model fit success: True
# 180
# Model fit success: True
# 181
# Model fit success: True
# 182
# Model fit success: True
# 183
# Model fit success: True
# 184
# Model fit success: True
# 185
# Model fit success: True
# 186
# Model fit success: True
# 187
# Model fit success: True
# 188
# Model fit success: True
# 189
# Model fit success: True
# 190
# Model fit success: True
# 191
# Model fit success: True
# 192
# Model fit success: True
# 193
# Model fit success: True
# 194
# Model fit success: True
# 195
# Model fit success: True
# 196
# Model fit success: True
# 197
# Model fit success: True
# 198
# Model fit success: True
# 199
# Model fit success: True
# 200
# Model fit success: True
# 201
# Model fit success: True
# 202
# Model fit success: True
# 203
# Model fit success: True
# 204
# Model fit success: True
# 205
# Model fit success: True
# 206
# Model fit success: True
# 207
# Model fit success: True
# 208
# Model fit success: True
# 209
# Model fit success: True
# 210
# Model fit success: True
#                              Metrics       MAE       MSE     R^2
# 0           Fourier Auction Vol (2A) 1.689e-03 5.164e-06 -2.2031
# 1  Fourier Auction Vol Adaptive (2B) 1.330e-03 3.522e-06 -1.1846
# 2     Fourier Auction Vol/ratio (2C) 1.671e-03 4.775e-06 -2.0954
# AAPL.O
# 0.0 done
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/gl/3w3l5x5s3zj3nmwpgjx_9gx80000gn/T/ipykernel_56494/3841505556.py in <module>
#       5 for stock_name in stock_list:
#       6     print(stock_name)
# ----> 7     results(df_stock, df_stockqqq, df_auction, df_auctionqqq, stock_name, J=1, P=15)
#
# /var/folders/gl/3w3l5x5s3zj3nmwpgjx_9gx80000gn/T/ipykernel_56494/3211363251.py in results(df_stock, df_stockqqq, df_auction, df_auctionqqq, stock_name, J, P)
#       7
#       8     stocks, avg_20day_volatility = process_data_moving_window(df_stockRIC, df_auctionRIC)
# ----> 9     MAE_2a, MSE_2a, R2_2a, fourier_window, predicted_fourier_window = fourier2A_results(stocks, avg_20day_volatility, J, P)
#      10     MAE_2b, MSE_2b, R2_2b, actual_fourier_window = fourier2B_results(stocks, avg_20day_volatility, fourier_window, J, P)
#      11     MAE_2c, MSE_2c, R2_2c = fourier2C_results(vol_df, actual_fourier_window, predicted_fourier_window)
#
# /var/folders/gl/3w3l5x5s3zj3nmwpgjx_9gx80000gn/T/ipykernel_56494/2169072168.py in fourier2A_results(stocks, avg_20day_volatility, J, P)
#      12         avg_20day_volatility_window = avg_20day_volatility[i:i+20]
#      13         fourier_window = flexible_fourier_regression(N=39, di=[], J=J, P=P) # 39 10-minute intervals in each trade day
# ---> 14         res_window = fourier_window.train(stocks_window, avg_20day_volatility_window, 0.0000005)
#      15         #print("optimizer success: {}".format(res_window.success))
#      16         #print("objective function (mse): {:.8f}".format(res_window.fun))
#
# ~/2021_Fall/Capstone Project/Vanguard-Volatility-Project/Module/baseModule/bayesFlexibleFourier.py in train(self, y, sigma_t, tol)
#      89         sigma_t = ravel(sigma_t)
#      90         assert sigma_t.shape[0] == y.shape[1], "sigma_t should have shape (t, ) and y should have shape (N, t)"
# ---> 91         res = minimize(lsq_fun_vec, self.x, tol=tol)
#      92
#      93         self.mu0 = res.x[0: J+1]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     616         return _minimize_cg(fun, x0, args, jac, callback, **options)
#     617     elif meth == 'bfgs':
# --> 618         return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     619     elif meth == 'newton-cg':
#     620         return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, **unknown_options)
#    1233         try:
#    1234             alpha_k, fc, gc, old_fval, old_old_fval, gfkp1 = \
# -> 1235                      _line_search_wolfe12(f, myfprime, xk, pk, gfk,
#    1236                                           old_fval, old_old_fval, amin=1e-100, amax=1e100)
#    1237         except _LineSearchError:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/optimize.py in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#    1003     extra_condition = kwargs.pop('extra_condition', None)
#    1004
# -> 1005     ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#    1006                              old_fval, old_old_fval,
#    1007                              **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      94     derphi0 = np.dot(gfk, pk)
#      95
# ---> 96     stp, fval, old_fval = scalar_search_wolfe1(
#      97             phi, derphi, old_fval, old_old_fval, derphi0,
#      98             c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     171             alpha1 = stp
#     172             phi1 = phi(stp)
# --> 173             derphi1 = derphi(stp)
#     174         else:
#     175             break
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py in derphi(s)
#      85
#      86     def derphi(s):
# ---> 87         gval[0] = fprime(xk + s*pk, *newargs)
#      88         if gradient:
#      89             gc[0] += 1
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in grad(self, x)
#     253         if not np.array_equal(x, self.x):
#     254             self._update_x_impl(x)
# --> 255         self._update_grad()
#     256         return self.g
#     257
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_grad(self)
#     236     def _update_grad(self):
#     237         if not self.g_updated:
# --> 238             self._update_grad_impl()
#     239             self.g_updated = True
#     240
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_grad()
#     153                 self._update_fun()
#     154                 self.ngev += 1
# --> 155                 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     156                                            **finite_diff_options)
#     157
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     484
#     485         if sparsity is None:
# --> 486             return _dense_difference(fun_wrapped, x0, f0, h,
#     487                                      use_one_sided, method)
#     488         else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     555             x = x0 + h_vecs[i]
#     556             dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 557             df = fun(x) - f0
#     558         elif method == '3-point' and use_one_sided[i]:
#     559             x1 = x0 + h_vecs[i]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in fun_wrapped(x)
#     435
#     436     def fun_wrapped(x):
# --> 437         f = np.atleast_1d(fun(x, *args, **kwargs))
#     438         if f.ndim > 1:
#     439             raise RuntimeError("`fun` return value has "
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     132             # Overwriting results in undefined behaviour because
#     133             # fun(self.x) will change self.x, with the two no longer linked.
# --> 134             return fun(np.copy(x), *args)
#     135
#     136         def update_fun():
#
# ~/2021_Fall/Capstone Project/Vanguard-Volatility-Project/Module/baseModule/bayesFlexibleFourier.py in lsq_fun_vec(x)
#      81                 sigma_J[:,:,j] = power(sigma_J[:,:,j], j)
#      82
# ---> 83             result = (sigma_J * component).sum(axis=-1)
#      84             cost = square(result - y).mean()
#      85
#
# KeyboardInterrupt:

# %% [markdown]
# # Check

# %%
stock_name = "MSFT.O"
df_stock = load_stock()
df_stockqqq = load_stockqqq()
df_auction = load_auction()
df_auctionqqq = load_auctionqqq()

# %%
df_stockRIC, df_stockqqq = load_stockdata(df_stock, df_stockqqq, stock_name)
df_auctionRIC, df_auctionqqq = load_auctiondata(df_auction, df_auctionqqq, stock_name)
vol_df = process_dfs(df_stockRIC, df_auctionRIC)

# %%
stocks, avg_20day_volatility = process_data_moving_window(df_stockRIC, df_auctionRIC)

# %%
stocks.shape
# Out:
# (39, 231)

# %%
MAE_2a, MSE_2a, R2_2a, fourier_window, predicted_fourier_window = fourier2A_results(stocks, avg_20day_volatility, 1, 15)
# Out:
# optimizer success: True
# objective function (mse): 0.00000066
# 0
# optimizer success: True
# objective function (mse): 0.00000126
# 1
# optimizer success: True
# objective function (mse): 0.00000113
# 2
# optimizer success: True
# objective function (mse): 0.00000103
# 3
# optimizer success: True
# objective function (mse): 0.00000090
# 4
# optimizer success: True
# objective function (mse): 0.00000075
# 5
# optimizer success: True
# objective function (mse): 0.00000073
# 6
# optimizer success: True
# objective function (mse): 0.00000072
# 7
# optimizer success: True
# objective function (mse): 0.00000069
# 8
# optimizer success: True
# objective function (mse): 0.00000077
# 9
# optimizer success: True
# objective function (mse): 0.00000083
# 10
# optimizer success: True
# objective function (mse): 0.00000095
# 11
# optimizer success: True
# objective function (mse): 0.00000102
# 12
# optimizer success: True
# objective function (mse): 0.00000105
# 13
# optimizer success: True
# objective function (mse): 0.00000105
# 14
# optimizer success: True
# objective function (mse): 0.00000103
# 15
# optimizer success: True
# objective function (mse): 0.00000103
# 16
# optimizer success: True
# objective function (mse): 0.00000106
# 17
# optimizer success: True
# objective function (mse): 0.00000109
# 18
# optimizer success: True
# objective function (mse): 0.00000114
# 19
# optimizer success: True
# objective function (mse): 0.00000117
# 20
# optimizer success: True
# objective function (mse): 0.00000116
# 21
# optimizer success: True
# objective function (mse): 0.00000120
# 22
# optimizer success: True
# objective function (mse): 0.00000121
# 23
# optimizer success: True
# objective function (mse): 0.00000129
# 24
# optimizer success: True
# objective function (mse): 0.00000060
# 25
# optimizer success: True
# objective function (mse): 0.00000057
# 26
# optimizer success: True
# objective function (mse): 0.00000056
# 27
# optimizer success: True
# objective function (mse): 0.00000055
# 28
# optimizer success: True
# objective function (mse): 0.00000042
# 29
# optimizer success: True
# objective function (mse): 0.00000032
# 30
# optimizer success: True
# objective function (mse): 0.00000033
# 31
# optimizer success: True
# objective function (mse): 0.00000030
# 32
# optimizer success: True
# objective function (mse): 0.00000029
# 33
# optimizer success: True
# objective function (mse): 0.00000029
# 34
# optimizer success: True
# objective function (mse): 0.00000092
# 35
# optimizer success: True
# objective function (mse): 0.00000088
# 36
# optimizer success: True
# objective function (mse): 0.00000082
# 37
# optimizer success: True
# objective function (mse): 0.00000076
# 38
# optimizer success: True
# objective function (mse): 0.00000072
# 39
# optimizer success: True
# objective function (mse): 0.00000064
# 40
# optimizer success: True
# objective function (mse): 0.00000060
# 41
# optimizer success: True
# objective function (mse): 0.00000053
# 42
# optimizer success: True
# objective function (mse): 0.00000052
# 43
# optimizer success: True
# objective function (mse): 0.00000051
# 44
# optimizer success: True
# objective function (mse): 0.00000048
# 45
# optimizer success: True
# objective function (mse): 0.00000048
# 46
# optimizer success: True
# objective function (mse): 0.00000048
# 47
# optimizer success: True
# objective function (mse): 0.00000047
# 48
# optimizer success: True
# objective function (mse): 0.00000046
# 49
# optimizer success: True
# objective function (mse): 0.00000044
# 50
# optimizer success: True
# objective function (mse): 0.00000043
# 51
# optimizer success: True
# objective function (mse): 0.00000042
# 52
# optimizer success: True
# objective function (mse): 0.00000043
# 53
# optimizer success: True
# objective function (mse): 0.00000042
# 54
# optimizer success: True
# objective function (mse): 0.00000043
# 55
# optimizer success: True
# objective function (mse): 0.00000045
# 56
# optimizer success: True
# objective function (mse): 0.00000044
# 57
# optimizer success: True
# objective function (mse): 0.00000052
# 58
# optimizer success: True
# objective function (mse): 0.00000056
# 59
# optimizer success: True
# objective function (mse): 0.00000100
# 60
# optimizer success: True
# objective function (mse): 0.00000128
# 61
# optimizer success: True
# objective function (mse): 0.00000157
# 62
# optimizer success: True
# objective function (mse): 0.00000105
# 63
# optimizer success: True
# objective function (mse): 0.00000108
# 64
# optimizer success: True
# objective function (mse): 0.00000113
# 65
# optimizer success: True
# objective function (mse): 0.00000116
# 66
# optimizer success: True
# objective function (mse): 0.00000119
# 67
# optimizer success: True
# objective function (mse): 0.00000122
# 68
# optimizer success: True
# objective function (mse): 0.00000124
# 69
# optimizer success: True
# objective function (mse): 0.00000124
# 70
# optimizer success: True
# objective function (mse): 0.00000124
# 71
# optimizer success: True
# objective function (mse): 0.00000125
# 72
# optimizer success: True
# objective function (mse): 0.00000125
# 73
# optimizer success: True
# objective function (mse): 0.00000125
# 74
# optimizer success: True
# objective function (mse): 0.00000128
# 75
# optimizer success: True
# objective function (mse): 0.00000128
# 76
# optimizer success: True
# objective function (mse): 0.00000128
# 77
# optimizer success: True
# objective function (mse): 0.00000125
# 78
# optimizer success: True
# objective function (mse): 0.00000193
# 79
# optimizer success: True
# objective function (mse): 0.00000074
# 80
# optimizer success: True
# objective function (mse): 0.00000146
# 81
# optimizer success: True
# objective function (mse): 0.00000133
# 82
# optimizer success: True
# objective function (mse): 0.00000121
# 83
# optimizer success: True
# objective function (mse): 0.00000113
# 84
# optimizer success: True
# objective function (mse): 0.00000124
# 85
# optimizer success: True
# objective function (mse): 0.00000131
# 86
# optimizer success: True
# objective function (mse): 0.00000137
# 87
# optimizer success: True
# objective function (mse): 0.00000144
# 88
# optimizer success: True
# objective function (mse): 0.00000152
# 89
# optimizer success: True
# objective function (mse): 0.00000090
# 90
# optimizer success: True
# objective function (mse): 0.00000090
# 91
# optimizer success: True
# objective function (mse): 0.00000091
# 92
# optimizer success: True
# objective function (mse): 0.00000091
# 93
# optimizer success: True
# objective function (mse): 0.00000092
# 94
# optimizer success: True
# objective function (mse): 0.00000154
# 95
# optimizer success: True
# objective function (mse): 0.00000142
# 96
# optimizer success: True
# objective function (mse): 0.00000133
# 97
# optimizer success: True
# objective function (mse): 0.00000122
# 98
# optimizer success: True
# objective function (mse): 0.00000117
# 99
# optimizer success: True
# objective function (mse): 0.00000109
# 100
# optimizer success: True
# objective function (mse): 0.00000101
# 101
# optimizer success: True
# objective function (mse): 0.00000101
# 102
# optimizer success: True
# objective function (mse): 0.00000104
# 103
# optimizer success: True
# objective function (mse): 0.00000116
# 104
# optimizer success: True
# objective function (mse): 0.00000100
# 105
# optimizer success: True
# objective function (mse): 0.00000095
# 106
# optimizer success: True
# objective function (mse): 0.00000090
# 107
# optimizer success: True
# objective function (mse): 0.00000089
# 108
# optimizer success: True
# objective function (mse): 0.00000083
# 109
# optimizer success: True
# objective function (mse): 0.00000080
# 110
# optimizer success: True
# objective function (mse): 0.00000079
# 111
# optimizer success: True
# objective function (mse): 0.00000078
# 112
# optimizer success: True
# objective function (mse): 0.00000085
# 113
# optimizer success: True
# objective function (mse): 0.00000084
# 114
# optimizer success: True
# objective function (mse): 0.00000083
# 115
# optimizer success: True
# objective function (mse): 0.00000083
# 116
# optimizer success: True
# objective function (mse): 0.00000082
# 117
# optimizer success: True
# objective function (mse): 0.00000078
# 118
# optimizer success: True
# objective function (mse): 0.00000081
# 119
# optimizer success: True
# objective function (mse): 0.00000076
# 120
# optimizer success: True
# objective function (mse): 0.00000075
# 121
# optimizer success: True
# objective function (mse): 0.00000071
# 122
# optimizer success: True
# objective function (mse): 0.00000151
# 123
# optimizer success: True
# objective function (mse): 0.00000139
# 124
# optimizer success: True
# objective function (mse): 0.00000131
# 125
# optimizer success: True
# objective function (mse): 0.00000125
# 126
# optimizer success: True
# objective function (mse): 0.00000120
# 127
# optimizer success: True
# objective function (mse): 0.00000115
# 128
# optimizer success: True
# objective function (mse): 0.00000111
# 129
# optimizer success: True
# objective function (mse): 0.00000106
# 130
# optimizer success: True
# objective function (mse): 0.00000100
# 131
# optimizer success: True
# objective function (mse): 0.00000099
# 132
# optimizer success: True
# objective function (mse): 0.00000102
# 133
# optimizer success: True
# objective function (mse): 0.00000107
# 134
# optimizer success: True
# objective function (mse): 0.00000115
# 135
# optimizer success: True
# objective function (mse): 0.00000119
# 136
# optimizer success: True
# objective function (mse): 0.00000120
# 137
# optimizer success: True
# objective function (mse): 0.00000123
# 138
# optimizer success: True
# objective function (mse): 0.00000121
# 139
# optimizer success: True
# objective function (mse): 0.00000120
# 140
# optimizer success: True
# objective function (mse): 0.00000118
# 141
# optimizer success: True
# objective function (mse): 0.00000113
# 142
# optimizer success: True
# objective function (mse): 0.00000045
# 143
# optimizer success: True
# objective function (mse): 0.00000046
# 144
# optimizer success: True
# objective function (mse): 0.00000050
# 145
# optimizer success: True
# objective function (mse): 0.00000056
# 146
# optimizer success: True
# objective function (mse): 0.00000058
# 147
# optimizer success: True
# objective function (mse): 0.00000065
# 148
# optimizer success: True
# objective function (mse): 0.00000066
# 149
# optimizer success: True
# objective function (mse): 0.00000072
# 150
# optimizer success: True
# objective function (mse): 0.00000078
# 151
# optimizer success: True
# objective function (mse): 0.00000082
# 152
# optimizer success: True
# objective function (mse): 0.00000084
# 153
# optimizer success: True
# objective function (mse): 0.00000081
# 154
# optimizer success: True
# objective function (mse): 0.00000079
# 155
# optimizer success: True
# objective function (mse): 0.00000076
# 156
# optimizer success: True
# objective function (mse): 0.00000083
# 157
# optimizer success: True
# objective function (mse): 0.00000072
# 158
# optimizer success: True
# objective function (mse): 0.00000070
# 159
# optimizer success: True
# objective function (mse): 0.00000061
# 160
# optimizer success: True
# objective function (mse): 0.00000053
# 161
# optimizer success: True
# objective function (mse): 0.00000045
# 162
# optimizer success: True
# objective function (mse): 0.00000040
# 163
# optimizer success: True
# objective function (mse): 0.00000037
# 164
# optimizer success: True
# objective function (mse): 0.00000036
# 165
# optimizer success: True
# objective function (mse): 0.00000036
# 166
# optimizer success: True
# objective function (mse): 0.00000036
# 167
# optimizer success: True
# objective function (mse): 0.00000037
# 168
# optimizer success: True
# objective function (mse): 0.00000038
# 169
# optimizer success: True
# objective function (mse): 0.00000042
# 170
# optimizer success: True
# objective function (mse): 0.00000045
# 171
# optimizer success: True
# objective function (mse): 0.00000048
# 172
# optimizer success: True
# objective function (mse): 0.00000047
# 173
# optimizer success: True
# objective function (mse): 0.00000047
# 174
# optimizer success: True
# objective function (mse): 0.00000047
# 175
# optimizer success: True
# objective function (mse): 0.00000049
# 176
# optimizer success: True
# objective function (mse): 0.00000038
# 177
# optimizer success: True
# objective function (mse): 0.00000039
# 178
# optimizer success: True
# objective function (mse): 0.00000041
# 179
# optimizer success: True
# objective function (mse): 0.00000042
# 180
# optimizer success: True
# objective function (mse): 0.00000042
# 181
# optimizer success: True
# objective function (mse): 0.00000043
# 182
# optimizer success: True
# objective function (mse): 0.00000043
# 183
# optimizer success: True
# objective function (mse): 0.00000044
# 184
# optimizer success: True
# objective function (mse): 0.00000046
# 185
# optimizer success: True
# objective function (mse): 0.00000055
# 186
# optimizer success: True
# objective function (mse): 0.00000059
# 187
# optimizer success: True
# objective function (mse): 0.00000059
# 188
# optimizer success: True
# objective function (mse): 0.00000056
# 189
# optimizer success: True
# objective function (mse): 0.00000051
# 190
# optimizer success: True
# objective function (mse): 0.00000048
# 191
# optimizer success: True
# objective function (mse): 0.00000046
# 192
# optimizer success: True
# objective function (mse): 0.00000046
# 193
# optimizer success: True
# objective function (mse): 0.00000046
# 194
# optimizer success: True
# objective function (mse): 0.00000044
# 195
# optimizer success: True
# objective function (mse): 0.00000042
# 196
# optimizer success: True
# objective function (mse): 0.00000043
# 197
# optimizer success: True
# objective function (mse): 0.00000043
# 198
# optimizer success: True
# objective function (mse): 0.00000039
# 199
# optimizer success: True
# objective function (mse): 0.00000042
# 200
# optimizer success: True
# objective function (mse): 0.00000043
# 201
# optimizer success: True
# objective function (mse): 0.00000046
# 202
# optimizer success: True
# objective function (mse): 0.00000049
# 203
# optimizer success: True
# objective function (mse): 0.00000049
# 204
# optimizer success: True
# objective function (mse): 0.00000047
# 205
# optimizer success: True
# objective function (mse): 0.00000037
# 206
# optimizer success: True
# objective function (mse): 0.00000035
# 207
# optimizer success: True
# objective function (mse): 0.00000033
# 208
# optimizer success: True
# objective function (mse): 0.00000031
# 209
# optimizer success: True
# objective function (mse): 0.00000031
# 210

# %%
MAE_2b, MSE_2b, R2_2b, actual_fourier_window = fourier2B_results(stocks, avg_20day_volatility, fourier_window, 1, 15)
# Out:
# 0
# Model fit success: True
# 1
# Model fit success: True
# 2
# Model fit success: True
# 3
# Model fit success: True
# 4
# Model fit success: True
# 5
# Model fit success: True
# 6
# Model fit success: True
# 7
# Model fit success: True
# 8
# Model fit success: True
# 9
# Model fit success: True
# 10
# Model fit success: True
# 11
# Model fit success: True
# 12
# Model fit success: True
# 13
# Model fit success: True
# 14
# Model fit success: True
# 15
# Model fit success: True
# 16
# Model fit success: True
# 17
# Model fit success: True
# 18
# Model fit success: True
# 19
# Model fit success: True
# 20
# Model fit success: True
# 21
# Model fit success: True
# 22
# Model fit success: True
# 23
# Model fit success: True
# 24
# Model fit success: True
# 25
# Model fit success: True
# 26
# Model fit success: True
# 27
# Model fit success: True
# 28
# Model fit success: True
# 29
# Model fit success: True
# 30
# Model fit success: True
# 31
# Model fit success: True
# 32
# Model fit success: True
# 33
# Model fit success: True
# 34
# Model fit success: True
# 35
# Model fit success: True
# 36
# Model fit success: True
# 37
# Model fit success: True
# 38
# Model fit success: True
# 39
# Model fit success: True
# 40
# Model fit success: True
# 41
# Model fit success: True
# 42
# Model fit success: True
# 43
# Model fit success: True
# 44
# Model fit success: True
# 45
# Model fit success: True
# 46
# Model fit success: True
# 47
# Model fit success: True
# 48
# Model fit success: True
# 49
# Model fit success: True
# 50
# Model fit success: True
# 51
# Model fit success: True
# 52
# Model fit success: True
# 53
# Model fit success: True
# 54
# Model fit success: True
# 55
# Model fit success: True
# 56
# Model fit success: True
# 57
# Model fit success: True
# 58
# Model fit success: True
# 59
# Model fit success: True
# 60
# Model fit success: True
# 61
# Model fit success: True
# 62
# Model fit success: True
# 63
# Model fit success: True
# 64
# Model fit success: True
# 65
# Model fit success: True
# 66
# Model fit success: True
# 67
# Model fit success: True
# 68
# Model fit success: True
# 69
# Model fit success: True
# 70
# Model fit success: True
# 71
# Model fit success: True
# 72
# Model fit success: True
# 73
# Model fit success: True
# 74
# Model fit success: True
# 75
# Model fit success: True
# 76
# Model fit success: True
# 77
# Model fit success: True
# 78
# Model fit success: True
# 79
# Model fit success: True
# 80
# Model fit success: True
# 81
# Model fit success: True
# 82
# Model fit success: True
# 83
# Model fit success: True
# 84
# Model fit success: True
# 85
# Model fit success: True
# 86
# Model fit success: True
# 87
# Model fit success: True
# 88
# Model fit success: True
# 89
# Model fit success: True
# 90
# Model fit success: True
# 91
# Model fit success: True
# 92
# Model fit success: True
# 93
# Model fit success: True
# 94
# Model fit success: True
# 95
# Model fit success: True
# 96
# Model fit success: True
# 97
# Model fit success: True
# 98
# Model fit success: True
# 99
# Model fit success: True
# 100
# Model fit success: True
# 101
# Model fit success: True
# 102
# Model fit success: True
# 103
# Model fit success: True
# 104
# Model fit success: True
# 105
# Model fit success: True
# 106
# Model fit success: True
# 107
# Model fit success: True
# 108
# Model fit success: True
# 109
# Model fit success: True
# 110
# Model fit success: True
# 111
# Model fit success: True
# 112
# Model fit success: True
# 113
# Model fit success: True
# 114
# Model fit success: True
# 115
# Model fit success: True
# 116
# Model fit success: True
# 117
# Model fit success: True
# 118
# Model fit success: True
# 119
# Model fit success: True
# 120
# Model fit success: True
# 121
# Model fit success: True
# 122
# Model fit success: True
# 123
# Model fit success: True
# 124
# Model fit success: True
# 125
# Model fit success: True
# 126
# Model fit success: True
# 127
# Model fit success: True
# 128
# Model fit success: True
# 129
# Model fit success: True
# 130
# Model fit success: True
# 131
# Model fit success: True
# 132
# Model fit success: True
# 133
# Model fit success: True
# 134
# Model fit success: True
# 135
# Model fit success: True
# 136
# Model fit success: True
# 137
# Model fit success: True
# 138
# Model fit success: True
# 139
# Model fit success: True
# 140
# Model fit success: True
# 141
# Model fit success: True
# 142
# Model fit success: True
# 143
# Model fit success: True
# 144
# Model fit success: True
# 145
# Model fit success: True
# 146
# Model fit success: True
# 147
# Model fit success: True
# 148
# Model fit success: True
# 149
# Model fit success: True
# 150
# Model fit success: True
# 151
# Model fit success: True
# 152
# Model fit success: True
# 153
# Model fit success: True
# 154
# Model fit success: True
# 155
# Model fit success: True
# 156
# Model fit success: True
# 157
# Model fit success: True
# 158
# Model fit success: True
# 159
# Model fit success: True
# 160
# Model fit success: True
# 161
# Model fit success: True
# 162
# Model fit success: True
# 163
# Model fit success: True
# 164
# Model fit success: True
# 165
# Model fit success: True
# 166
# Model fit success: True
# 167
# Model fit success: True
# 168
# Model fit success: True
# 169
# Model fit success: True
# 170
# Model fit success: True
# 171
# Model fit success: True
# 172
# Model fit success: True
# 173
# Model fit success: True
# 174
# Model fit success: True
# 175
# Model fit success: True
# 176
# Model fit success: True
# 177
# Model fit success: True
# 178
# Model fit success: True
# 179
# Model fit success: True
# 180
# Model fit success: True
# 181
# Model fit success: True
# 182
# Model fit success: True
# 183
# Model fit success: True
# 184
# Model fit success: True
# 185
# Model fit success: True
# 186
# Model fit success: True
# 187
# Model fit success: True
# 188
# Model fit success: True
# 189
# Model fit success: True
# 190
# Model fit success: True
# 191
# Model fit success: True
# 192
# Model fit success: True
# 193
# Model fit success: True
# 194
# Model fit success: True
# 195
# Model fit success: True
# 196
# Model fit success: True
# 197
# Model fit success: True
# 198
# Model fit success: True
# 199
# Model fit success: True
# 200
# Model fit success: True
# 201
# Model fit success: True
# 202
# Model fit success: True
# 203
# Model fit success: True
# 204
# Model fit success: True
# 205
# Model fit success: True
# 206
# Model fit success: True
# 207
# Model fit success: True
# 208
# Model fit success: True
# 209
# Model fit success: True
# 210
# Model fit success: True

# %%
MAE_2c, MSE_2c, R2_2c = fourier2C_results(vol_df, actual_fourier_window, predicted_fourier_window)

# %%
MAE_2c
# Out:
# 0.0016707010972491635

# %%
# ## Hyper-parameter tuning using first 200 days

# params_MAE = (0,0)
# params_MSE = (0,0)
# params_r_squared = (0,0)

# MAE_min = float('inf')
# MSE_min = float('inf')
# R_squared_max = -float('inf')

# for j in [1,2,3,4]:
#     for p in [15,17,19,21,23,25]:      
#         print('Checking for:', (j,p))
        
#         # Train the model based on first 200 days
#         fourier = flexible_fourier_regression(N=39, di=[], J=j, P=p) # 39 10-minute intervals in each trade day
#         res = fourier.train(stocks200, avg_20day_volatility200, 0.0000005) 

#         # Prediction on the last 31 days
#         results = fourier.predict(avg_20day_volatility[-31:])

#         if mean_absolute_error(stocks.T[-31:,-1], results[-1,:]) < MAE_min:
#             params_MAE = (j,p)
#             MAE_min = mean_absolute_error(stocks.T[-31:,-1], results[-1,:])
            
#         if mean_squared_error(stocks.T[-31:,-1], results[-1,:]) < MSE_min:
#             params_MSE = (j,p)
#             MSE_min = mean_squared_error(stocks.T[-31:,-1], results[-1,:])
            
#         if r2_score(stocks.T[-31:,-1], results[-1,:]) > R_squared_max:
#             params_r_squared = (j,p)
#             R_squared_max = r2_score(stocks.T[-31:,-1], results[-1,:])

# print(params_MAE)
# print(params_MSE)
# print(params_r_squared)
# print(R_squared_max)
# Out:
# (3, 19)
# (4, 19)
# (4, 19)
